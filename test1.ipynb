# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy 
from scipy.optimize import curve_fit
from scipy.stats import chi2 as chi
from scipy.stats import pearsonr 
from prova import apri

# %%
apri("200423_americio.dat")
e=np.loadtxt("new_file.txt", unpack=True)

ex=np.array(e)

binstot = 2000

fitinf = 258
fitsup = 350


ex=ex[ex>fitinf]
ex=ex[ex<fitsup]



plt.hist(e, bins=binstot)

R = (max(e) - min(e)) / binstot 

binsfit = round((fitsup - fitinf) / R)
plt.title('Calibrazione')
plt.xlabel('Canali')
plt.ylabel(' Events ')
plt.hist(ex,bins=binsfit)
# Out:
# (array([ 9878., 11970., 14570., 17383., 20885., 24834., 28404., 32017.,
#         34846., 36997., 37590., 28677., 36166., 33328., 29615., 25311.,
#         20939., 16355., 12606.,  9063.,  6461.,  4364.,  2869.]),
#  array([259.        , 262.91304348, 266.82608696, 270.73913043,
#         274.65217391, 278.56521739, 282.47826087, 286.39130435,
#         290.30434783, 294.2173913 , 298.13043478, 302.04347826,
#         305.95652174, 309.86956522, 313.7826087 , 317.69565217,
#         321.60869565, 325.52173913, 329.43478261, 333.34782609,
#         337.26086957, 341.17391304, 345.08695652, 349.        ]),
#  <BarContainer object of 23 artists>)
